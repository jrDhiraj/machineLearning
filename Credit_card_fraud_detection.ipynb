# %% [markdown]
# <a href="https://colab.research.google.com/github/jrDhiraj/machineLearning/blob/main/Credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/creditcardDataset.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (71396, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71396 entries, 0 to 71395
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    71396 non-null  int64
#  1   V1      71396 non-null  float64
#  2   V2      71396 non-null  float64
#  3   V3      71396 non-null  float64
#  4   V4      71396 non-null  float64
#  5   V5      71396 non-null  float64
#  6   V6      71396 non-null  float64
#  7   V7      71396 non-null  float64
#  8   V8      71396 non-null  float64
#  9   V9      71396 non-null  float64
#  10  V10     71396 non-null  float64
#  11  V11     71396 non-null  float64
#  12  V12     71396 non-null  float64
#  13  V13     71396 non-null  float64
#  14  V14     71396 non-null  float64
#  15  V15     71396 non-null  float64
#  16  V16     71396 non-null  float64
#  17  V17     71396 non-null  float64
#  18  V18     71396 non-null  float64
#  19  V19     71396 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df = df.dropna(axis=0)

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.shape
# Out:
# (71395, 31)

# %%
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  71395.000000  71395.000000  71395.000000  71395.000000  71395.000000
# mean   35055.294278     -0.250524     -0.024295      0.680184      0.168661
# std    14520.794019      1.878015      1.662192      1.416346      1.374622
# min        0.000000    -56.407510    -72.715728    -33.680984     -5.172595
# 25%    28974.000000     -1.010299     -0.593571      0.193392     -0.725858
# 50%    38225.000000     -0.248116      0.072334      0.770237      0.187344
# 75%    46034.000000      1.153522      0.727549      1.402154      1.052365
# max    54280.000000      1.960497     18.902453      4.226108     16.715537
#
#                  V5            V6            V7            V8            V9  \
# count  71395.000000  71395.000000  71395.000000  71395.000000  71395.000000
# mean      -0.271041      0.099779     -0.114767      0.056621      0.015430
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    71218
# 1.0      177
# Name: count, dtype: int64

# %%
X_old = df.drop('Class', axis=1)
Y_old = df['Class']

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
X_train_old, X_test_old, Y_train_old, Y_test_old = train_test_split(X_old, Y_old, test_size=0.2, stratify=Y_old, random_state=42)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_old = scaler.fit_transform(X_train_old)
X_test_old = scaler.transform(X_test_old)

from sklearn.linear_model import LogisticRegression
model_old = LogisticRegression(class_weight='balanced', random_state=42)
model_old.fit(X_train_old, Y_train_old)

y_pred_old = model_old.predict(X_test_old)
acc = accuracy_score(Y_test_old, y_pred_old)
print(acc)
# Out:
# 0.9792702570207997

# %%
not_fraud = df[df.Class == 0]
fraud = df[df.Class == 1]

# %%
print(not_fraud.shape)
print(fraud.shape)
# Out:
# (71218, 31)
# (177, 31)

# %% [markdown]
# Statiiclal measure

# %%
not_fraud.Amount.describe()
# Out:
# count    71218.000000
# mean        97.028781
# std        270.410639
# min          0.000000
# 25%          7.680000
# 50%         26.550000
# 75%         88.500000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     177.000000
# mean       95.719153
# std       219.167165
# min         0.000000
# 25%         1.000000
# 50%         7.610000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %% [markdown]
# complare the value for both transaction

# %%
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    35066.440352 -0.234234 -0.036579  0.704647  0.155872 -0.259090
# 1.0    30570.542373 -6.805243  4.918403 -9.162545  5.314564 -5.079731
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.105218 -0.097289  0.048430  0.023374  ...  0.044548 -0.031241
# 1.0   -2.088712 -7.147266  3.352192 -3.180791  ...  0.426844  0.822681
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106249 -0.038231  0.006499  0.135292  0.022316  0.001788  0.002561
# 1.0   -0.189293 -0.245318 -0.073800  0.248813  0.105956  0.564291  0.045180
#
#           Amount
# Class
# 0.0    97.028781
# 1.0    95.719153
#
# [2 rows x 30 columns]

# %% [markdown]
# Build sample Dataset containing Similar Distribution of noraml transaction

# %%
not_fraud_sample = not_fraud.sample(n=177)

# %%
new_df = pd.concat([not_fraud_sample, fraud], axis=0)

# %%
new_df.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 59063  48677 -5.155411 -6.159539  0.374120  1.528838  7.335025 -5.561229
# 22113  32043 -1.265189 -0.034603  2.794814  1.206049 -0.551902  0.493262
# 66372  52016 -0.944844  0.874080 -0.195055 -1.716274 -0.305160 -1.572039
# 3959    3585 -0.456682  0.916441  1.251241  0.047662  0.230838 -0.595781
# 55167  46817  1.295721 -0.138160  0.034523 -0.549061  0.134807  0.545900
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 59063 -3.885676  0.588598 -0.036773  ...  0.588082 -0.477883  1.205845
# 22113 -0.449326  0.616768 -0.141342  ...  0.434117  1.027770  0.047115
# 66372  0.419484 -0.129966 -1.391966  ...  0.423215  1.072213  0.053074
# 3959   0.514008  0.120227 -0.266849  ... -0.236612 -0.648139  0.046800
# 55167 -0.403269  0.192956  0.190896  ... -0.142189 -0.376123 -0.055846
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_df.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 68633  53076  1.296231  0.417447  0.193963  0.901644  0.130531 -0.371634
# 69498  53451  0.385108  1.217620 -1.953872  2.087076 -1.144225 -0.576888
# 69980  53658 -1.739341  1.344521 -0.534379  3.195291 -0.416196 -1.261961
# 70141  53727 -1.649279  1.263974 -1.050826  2.237991 -2.527889 -0.889940
# 70589  53937 -2.042608  1.573578 -2.372652 -0.572676 -2.097353 -0.174142
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 68633  0.158126 -0.202669 -0.079512  ... -0.112114 -0.220002 -0.121022
# 69498 -2.582865  0.643230 -1.191233  ...  0.594623  0.372144 -0.310456
# 69980 -2.340991  0.713004 -1.416265  ...  0.383180 -0.213952 -0.336640
# 70141 -2.355254  0.854659 -1.281243  ...  0.679176  0.731907  0.333045
# 70589 -3.039520 -1.634233 -0.594809  ... -0.723326  0.501222 -0.696892
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_df.shape
# Out:
# (354, 31)

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0.0    177
# 1.0    177
# Name: count, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    33153.220339 -0.221231  0.071989  0.914797  0.213393 -0.101591
# 1.0    30570.542373 -6.805243  4.918403 -9.162545  5.314564 -5.079731
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.047936 -0.135981 -0.000924  0.003120  ...  0.054054  0.005458
# 1.0   -2.088712 -7.147266  3.352192 -3.180791  ...  0.426844  0.822681
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.057420 -0.026254  0.063259  0.134214  0.025530  0.054804  0.031495
# 1.0   -0.189293 -0.245318 -0.073800  0.248813  0.105956  0.564291  0.045180
#
#           Amount
# Class
# 0.0    69.307910
# 1.0    95.719153
#
# [2 rows x 30 columns]

# %%
new_df.describe()
# Out:
#                Time          V1          V2          V3          V4  \
# count    354.000000  354.000000  354.000000  354.000000  354.000000
# mean   31861.881356   -3.513237    2.495196   -4.123874    2.763978
# std    15103.744482    6.678569    3.970508    7.926552    3.453713
# min       10.000000  -30.552380   -6.900315  -31.103685   -3.543040
# 25%    20513.250000   -3.879146    0.010543   -5.801749    0.247470
# 50%    35902.500000   -1.002734    1.141576   -0.184064    1.717986
# 75%    42463.250000    0.694551    3.899635    0.993652    5.501054
# max    54116.000000    1.490690   16.713389    3.757584   11.927512
#
#                V5          V6          V7          V8          V9  ...  \
# count  354.000000  354.000000  354.000000  354.000000  354.000000  ...
# mean    -2.590661   -1.020388   -3.641623    1.675634   -1.588836  ...
# std      5.128283    1.777693    5.952029    4.114019    2.543333  ...
# ...

# %%
new_df.Class.value_counts()
# Out:
# Class
# 0.0    177
# 1.0    177
# Name: count, dtype: int64

# %%
X = df.drop(columns='Class', axis=1)
Y = df['Class']

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
acc = accuracy_score(Y_test, y_pred)
print(acc)
# Out:
# 0.9985993416905946
